# %% [markdown]
# # Data Context & Dictionary

# %% [markdown]
# ## IBM HR Employee Attrition

# %% [markdown]
# Berikut ini adalah data fiktif tentang faktor-faktor yang menyebabkan terjadinya pergantian karyawan di perusahaan IBM
#
# | Kolom                        | Nilai | Keterangan    |
# | ---------------------------- | ----- | ------------- |
# | **Education**                | 1     | Below College |
# |                              | 2     | College       |
# |                              | 3     | Bachelor      |
# |                              | 4     | Master        |
# |                              | 5     | Doctor        |
# | **EnvironmentSatisfaction**  | 1     | Low           |
# |                              | 2     | Medium        |
# |                              | 3     | High          |
# |                              | 4     | Very High     |
# | **JobInvolvement**           | 1     | Low           |
# |                              | 2     | Medium        |
# |                              | 3     | High          |
# |                              | 4     | Very High     |
# | **JobSatisfaction**          | 1     | Low           |
# |                              | 2     | Medium        |
# |                              | 3     | High          |
# |                              | 4     | Very High     |
# | **PerformanceRating**        | 1     | Low           |
# |                              | 2     | Good          |
# |                              | 3     | Excellent     |
# |                              | 4     | Outstanding   |
# | **RelationshipSatisfaction** | 1     | Low           |
# |                              | 2     | Medium        |
# |                              | 3     | High          |
# |                              | 4     | Very High     |
# | **WorkLifeBalance**          | 1     | Bad           |
# |                              | 2     | Good          |
# |                              | 3     | Better        |
# |                              | 4     | Best          |

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Extraction

# %%
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Data Inspection

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Jumlah Pegawai IBM
jumlah = df.shape[0]
print(jumlah)
# Out:
# 1470

# %% [markdown]
# ## Data Structure Summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Data Type Inspection

# %%
# menampilkan daftar tipe data dari dataframe
cols = list(df.dtypes.apply(lambda x: x.name).unique())
cols
# Out:
# ['int64', 'object']

# %% [markdown]
# ## Nilai Unik di Kolom Kategorikal

# %%
df[['Department','EnvironmentSatisfaction','JobInvolvement','JobLevel','JobSatisfaction','PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']] = df[['Department','EnvironmentSatisfaction','JobInvolvement','JobLevel','JobSatisfaction','PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']].astype('str')

# %%
# Jumlah kolom kategori
cat_columns = list(df.select_dtypes(include='object').columns)
n = len(cat_columns)
print(cat_columns)
print(n)
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance']
# 16

# %%
# List untuk menyimpan tiap dataframe
tabel_kategori = []

for col in cat_columns:
    df_temp = df[col].value_counts().reset_index().rename(columns={
        'index': f'Nilai Unik ({col})',
        col: 'Jumlah'
    })
    # Sisipkan nama kolom & jumlah nilai unik sebagai metadata (optional)
    print(f"\n📌 Kolom: {col}  — Jumlah nilai unik: {df[col].nunique()}")
    display(df_temp)  # Jika pakai Jupyter, tampil sebagai tabel
    tabel_kategori.append((col, df_temp))
# Out:
# 📌 Kolom: Attrition  — Jumlah nilai unik: 2
#   Nilai Unik (Attrition)  Jumlah
# 0                     No    1233
# 1                    Yes     237
# 📌 Kolom: BusinessTravel  — Jumlah nilai unik: 3
#   Nilai Unik (BusinessTravel)  Jumlah
# 0               Travel_Rarely    1043
# 1           Travel_Frequently     277
# 2                  Non-Travel     150
# 📌 Kolom: Department  — Jumlah nilai unik: 3
#   Nilai Unik (Department)  Jumlah
# 0  Research & Development     961
# 1                   Sales     446
# 2         Human Resources      63
# 📌 Kolom: EducationField  — Jumlah nilai unik: 6
#   Nilai Unik (EducationField)  Jumlah
# 0               Life Sciences     606
# 1                     Medical     464
# 2                   Marketing     159
# 3            Technical Degree     132
# 4                       Other      82
# 5             Human Resources      27
# 📌 Kolom: EnvironmentSatisfaction  — Jumlah nilai unik: 4
#   Nilai Unik (EnvironmentSatisfaction)  Jumlah
# ...

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Numerical Columns Statistics

# %%
# statistik kolom numerik
df.describe().T
# Out:
#                           count          mean          std     min      25%  \
# Age                      1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome         1470.0      9.192517     8.106864     1.0     2.00
# Education                1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount            1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber           1470.0   1024.865306   602.024335     1.0   491.25
# HourlyRate               1470.0     65.891156    20.329428    30.0    48.00
# MonthlyIncome            1470.0   6502.931293  4707.956783  1009.0  2911.00
# MonthlyRate              1470.0  14313.103401  7117.786044  2094.0  8047.00
# NumCompaniesWorked       1470.0      2.693197     2.498009     0.0     1.00
# PercentSalaryHike        1470.0     15.209524     3.659938    11.0    12.00
# ...

# %% [markdown]
# ### Categorical Columns Statistics

# %%
# statistik kolom non numerik
df.describe(include=['object']).T
# Out:
#                          count unique                     top  freq
# Attrition                 1470      2                      No  1233
# BusinessTravel            1470      3           Travel_Rarely  1043
# Department                1470      3  Research & Development   961
# EducationField            1470      6           Life Sciences   606
# EnvironmentSatisfaction   1470      4                       3   453
# Gender                    1470      2                    Male   882
# JobInvolvement            1470      4                       3   868
# JobLevel                  1470      5                       1   543
# JobRole                   1470      9         Sales Executive   326
# JobSatisfaction           1470      4                       4   459
# MaritalStatus             1470      3                 Married   673
# Over18                    1470      1                       Y  1470
# OverTime                  1470      2                      No  1054
# ...

# %% [markdown]
# ## Batch Visualization of Categorical and Numerical Distributions via Subplots

# %% [markdown]
# ### Categorical Data

# %%
# Hitung ukuran grid yang pas
n_cols = 3  # Misal 3 kolom
n_rows = (n + n_cols - 1) // n_cols  # Pembulatan ke atas

# Buat subplot
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(n_cols * 5, n_rows * 4))
axes = axes.flatten()  # Ubah ke array 1D agar mudah di-loop

# Loop dan plot
for i, col in enumerate(cat_columns):
    df[col].value_counts().plot(kind='bar', ax=axes[i], title=col, color='salmon', edgecolor='black')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Jumlah')
    axes[i].tick_params(axis='x', rotation=90)

# Hapus axis sisa jika jumlah kolom tidak pas
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Numerical Data

# %%
num_columns = list(df.select_dtypes(include=['int64', 'float64']).columns)
n = len(num_columns)
print(num_columns)
print(n)
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
# 19

# %%
n_cols = 4  # Misal 3 kolom
n_rows = (n + n_cols - 1) // n_cols  # Pembulatan ke atas

# Buat subplot
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(n_cols * 5, n_rows * 4))
axes = axes.flatten()  # Ubah ke array 1D agar mudah di-loop

# Loop dan plot
for i, col in enumerate(num_columns):
    df[col].value_counts().plot(kind='hist', ax=axes[i], title=col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Jumlah')
    axes[i].tick_params(axis='x', rotation=-45)

# Hapus axis sisa jika jumlah kolom tidak pas
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Automatic EDA

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_file("report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # `Attrition` Analysis

# %%
cat_columns_targetless = df.select_dtypes(include='object').columns.drop('Attrition')  # Kecuali target

# List hasil
ringkasan_attrition = []

for col in cat_columns:
    # Hitung distribusi Attrition untuk setiap kategori
    tab = pd.crosstab(df[col], df['Attrition'], margins=True)
    
    # Hitung rasio Attrition 'Yes' terhadap total tiap kategori
    tab['Attrition_Yes_Ratio (%)'] = round(tab['Yes'] / tab['All'] * 100, 2)
    
    # Hapus baris 'All' agar tidak tercampur
    tab = tab.drop(index='All')
    
    # Reset index agar rapi ditampilkan
    tab = tab.reset_index()
    
    print(f"\n📌 Ringkasan Attrition berdasarkan: {col}")
    display(tab)
    
    # Simpan jika ingin digunakan kembali
    ringkasan_attrition.append((col, tab))
# Out:
# 📌 Ringkasan Attrition berdasarkan: Attrition
# Attrition Attrition    No  Yes   All  Attrition_Yes_Ratio (%)
# 0                No  1233    0  1233                      0.0
# 1               Yes     0  237   237                    100.0
# 📌 Ringkasan Attrition berdasarkan: BusinessTravel
# Attrition     BusinessTravel   No  Yes   All  Attrition_Yes_Ratio (%)
# 0                 Non-Travel  138   12   150                     8.00
# 1          Travel_Frequently  208   69   277                    24.91
# 2              Travel_Rarely  887  156  1043                    14.96
# 📌 Ringkasan Attrition berdasarkan: Department
# Attrition              Department   No  Yes  All  Attrition_Yes_Ratio (%)
# 0                 Human Resources   51   12   63                    19.05
# 1          Research & Development  828  133  961                    13.84
# 2                           Sales  354   92  446                    20.63
# 📌 Ringkasan Attrition berdasarkan: EducationField
# ...

# %% [markdown]
# # Export to Tableau

# %%
# Salin dataframe asli
df_new = df.copy()

# Mapping dictionary berdasarkan deskripsi Kaggle
edu_map = {
    '1': 'Below College', '2': 'College', '3': 'Bachelor', '4': 'Master', '5': 'Doctor'
}

satisfaction_map = {
    '1': 'Low', '2': 'Medium', '3': 'High', '4': 'Very High'
}

performance_map = {
    '1': 'Low', '2': 'Good', '3': 'Excellent', '4': 'Outstanding'
}

wlb_map = {
    '1': 'Bad', '2': 'Good', '3': 'Better', '4': 'Best'
}

# Terapkan mapping
df_new['Education'] = df_new['Education'].map(edu_map)
df_new['EnvironmentSatisfaction'] = df_new['EnvironmentSatisfaction'].map(satisfaction_map)
df_new['JobInvolvement'] = df_new['JobInvolvement'].map(satisfaction_map)
df_new['JobSatisfaction'] = df_new['JobSatisfaction'].map(satisfaction_map)
df_new['PerformanceRating'] = df_new['PerformanceRating'].map(performance_map)
df_new['RelationshipSatisfaction'] = df_new['RelationshipSatisfaction'].map(satisfaction_map)
df_new['WorkLifeBalance'] = df_new['WorkLifeBalance'].map(wlb_map)

# Export ke CSV
df_new.to_csv("/IBM HR Analytics Employee Attrition and Performance/data_ibm_hr_for_tableau.csv", index=False)

print("✅ Dataset berhasil disiapkan dan diekspor ke 'data_ibm_hr_for_tableau.csv'")
# Out:
# ✅ Dataset berhasil disiapkan dan diekspor ke 'data_ibm_hr_for_tableau.csv'

# %%
df_new.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1       NaN  Life Sciences              1               1
# 1                 8       NaN  Life Sciences              1               2
# 2                 2       NaN          Other              1               4
# 3                 3       NaN  Life Sciences              1               5
# 4                 2       NaN        Medical              1               7
#
#    ... RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...
